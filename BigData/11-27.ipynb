# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/ASOS_month(종관기상관측)).csv",encoding='cp949')
df
# Out:
#         지점 지점명       일시  평균기온(°C)  최고기온(°C)  최저기온(°C)  평균상대습도(%)  \
# 0       90  속초  2000-01      -0.4       9.9     -10.9       56.0
# 1       90  속초  2000-02      -0.1       9.2      -8.6       41.0
# 2       90  속초  2000-03       6.9      18.5      -4.2       45.0
# 3       90  속초  2000-04      11.2      24.1       2.4       55.0
# 4       90  속초  2000-05      14.3      30.5       6.2       79.0
# ...    ...  ..      ...       ...       ...       ...        ...
# 24837  295  남해  2023-05      18.0      29.1       7.9       75.0
# 24838  295  남해  2023-06      22.5      30.6      15.8       78.0
# 24839  295  남해  2023-07      25.4      33.5      20.2       88.0
# 24840  295  남해  2023-08      27.1      35.1      22.4       82.0
# 24841  295  남해  2023-09      23.8      31.1      17.1       82.0
#
#        월합강수량(00~24h만)(mm)  일최다강수량(mm)  1시간최다강수량(mm)  10분최다강수량(mm)  평균풍속(m/s)  \
# 0                    90.2        31.5           NaN           NaN        2.2
# ...

# %%
df['연'] = df['일시'].apply(lambda x:x.split('-')[0])

# %%
tdf = df[['평균기온(°C)','지점명','연']].groupby(['지점명','연']).mean()
tdf
# Out:
#            평균기온(°C)
# 지점명 연
# 강릉  2000  13.466667
#     2001  13.383333
#     2002  13.175000
#     2003  12.683333
#     2004  14.083333
# ...             ...
# 흑산도 2019  14.066667
#     2020  14.100000
#     2021  15.258333
#     2022  13.983333
#     2023  15.044444
#
# [2098 rows x 1 columns]

# %%
tdf.loc['속초','2000']
# Out:
# 평균기온(°C)    12.0
# Name: (속초, 2000), dtype: float64

# %%
for region in df['지점명'].unique():
    print(tdf.loc[region,'2000'])
# Out:
# 평균기온(°C)    12.0
# Name: (속초, 2000), dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\junhy\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File c:\Users\junhy\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\junhy\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
tdf3 = tdf.loc['속초']

# %%
tdf3.loc['2000']
# Out:
# 평균기온(°C)    12.0
# Name: 2000, dtype: float64

# %%
tdf.loc['q']
# Out:
# array(['속초', '북춘천', '철원', '동두천', '파주', '대관령', '춘천', '백령도', '북강릉', '강릉',
#        '동해', '서울', '인천', '원주', '울릉도', '수원', '영월', '충주', '서산', '울진', '청주',
#        '대전', '추풍령', '안동', '상주', '포항', '군산', '대구', '전주', '울산', '창원', '광주',
#        '부산', '통영', '무안', '목포', '여수', '흑산도', '완도', '고창', '순천', '진도(첨찰산)',
#        '대구(기)', '홍성', '서청주', '제주', '고산', '성산', '서귀포', '진주', '강화', '양평',
#        '이천', '인제', '홍천', '태백', '정선군', '제천', '보은', '천안', '보령', '부여', '금산',
#        '세종', '부안', '임실', '정읍', '남원', '장수', '고창군', '영광군', '김해시', '순창군',
#        '북창원', '주암', '양산시', '보성군', '강진군', '장흥', '해남', '고흥', '의령군', '함양군',
#        '성산포', '광양시', '진도군', '봉화', '영주', '문경', '청송군', '영덕', '의성', '구미',
#        '영천', '경주시', '거창', '합천', '밀양', '산청', '거제', '남해'], dtype=object)

# %%
for region in df['지점명'].unique():
    print(tdf.loc[region,'2023'])
# Out:
# 평균기온(°C)    15.1
# Name: (속초, 2023), dtype: float64
# 평균기온(°C)    14.2
# Name: (북춘천, 2023), dtype: float64
# 평균기온(°C)    13.622222
# Name: (철원, 2023), dtype: float64
# 평균기온(°C)    14.544444
# Name: (동두천, 2023), dtype: float64
# 평균기온(°C)    13.822222
# Name: (파주, 2023), dtype: float64
# 평균기온(°C)    10.522222
# Name: (대관령, 2023), dtype: float64
# 평균기온(°C)    14.555556
# Name: (춘천, 2023), dtype: float64
# 평균기온(°C)    13.7
# Name: (백령도, 2023), dtype: float64
# 평균기온(°C)    15.455556
# Name: (북강릉, 2023), dtype: float64
# 평균기온(°C)    17.177778
# Name: (강릉, 2023), dtype: float64
# 평균기온(°C)    15.788889
# Name: (동해, 2023), dtype: float64
# 평균기온(°C)    16.1
# Name: (서울, 2023), dtype: float64
# 평균기온(°C)    15.155556
# Name: (인천, 2023), dtype: float64
# 평균기온(°C)    15.511111
# Name: (원주, 2023), dtype: float64
# 평균기온(°C)    15.766667
# Name: (울릉도, 2023), dtype: float64
# 평균기온(°C)    15.266667
# Name: (수원, 2023), dtype: float64
# 평균기온(°C)    14.488889
# Name: (영월, 2023), dtype: float64
# ...

# %%
tdf.loc['무안']
# Out:
#        평균기온(°C)
# 연
# 2000  11.714286
